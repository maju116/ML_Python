# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import random
import os
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

tf.__version__
# Out:
# 2023-04-20 17:11:59.438216: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 17:12:00.179140: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.2/lib64:/usr/local/cuda-11.2/extras/CUPTI/lib64
# 2023-04-20 17:12:00.179257: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.2/lib64:/usr/local/cuda-11.2/extras/CUPTI/lib64
# 2023-04-20 17:12:00.179264: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# '2.11.0'

# %% [markdown]
# Zacznijmy od prostej funkcji `f (x) = x ^ 2 + 1` i jej pochodnej `f'(x) = 2x`. Znalezienie minimum `f(x)` jest proste w tej sytuacji: minimalna wartość jest równa `1`, gdy `x == 0`. Zauważ, że nasza pochodna `f'(x)` równa się `0` dokładnie w tym punkcie (jeśli wartość pochodnej `f'(x) `jest równa `0` w punkcie `x == x0`, funkcja `f(x)` ma lokalne / globalne minimum / maksimum / punkt zwrotny w `x0`).

# %%
f = lambda x: x**2 + 1
grad_f = lambda x: 2*x

sample_data = pd.DataFrame({
    'x': np.arange(-2, 2, 0.05)
})
sample_data["y"] = f(sample_data.x)
sample_data["grad"] = grad_f(sample_data.x)

# %%
sample_data.plot(x = 'x')
# Out:
# <AxesSubplot:xlabel='x'>

# %% [markdown]
# Wniosek, jeśli nie możemy bezpośrednio znaleźć minimum funkcji `f(x)`, zawsze możemy spróbować sprawdzić, gdzie pochodna `f'(x)` jest równa `0` (a dla wielu rozwiązań sprawdź, która z nich jest minimum). To świetnie, ale co zrobić, gdy nie możemy rozwiązać równania `f'(x) == 0`? Żaden problem, zawsze możemy użyć bardzo prostego algorytmu o nazwie **Gradient Descent**:
#
#
# 1. Zacznij od wartości początkowej parametrów (x, y, beta, cokolwiek, ...)
# 2. Uaktualnij parametry formułą `param_new := param_old - LR * f'(param_old)` gdzie `LR` jest hiperparametrem zwanym **learning rate**. Wypróbujmy to dla naszej funkcji. Wypróbuj różne wartości learning rate, takie jak `0.1`, `0.01` i `1`

# %%
x0 = 1.345
lr = 1
epochs = 30 # Liczba epok, czyli liczba aktualizacji wag

def GD_ordinary_fun(f, grad_f, x0, lr, epochs):
    x = x0
    results = pd.DataFrame({
        'x': [x0],
        'y': [f(x0)],
        'grad': [grad_f(x0)]
    })
    for i in range(1, epochs + 1):
        x = x - lr * grad_f(x) # Gradient Descent
        print("Updated x value:", round(x, 8), ". Updated f(x) value:", round(f(x), 8))
        results = results.append(pd.DataFrame({
            'x': [x],
            'y': [f(x)],
            'grad': [grad_f(x)]
    }))
    return results

task1 = GD_ordinary_fun(f, grad_f, x0, lr, epochs)
# Out:
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# Updated x value: -1.345 . Updated f(x) value: 2.809025
# Updated x value: 1.345 . Updated f(x) value: 2.809025
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/3195584465.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({

# %%
ax = sample_data.plot(x = 'x')
task1.plot(ax = ax, x = 'x', y = 'y', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# Jeśli teraz możemy zaimplementować Gradient Descent dla prostej funkcji z jednym parametrem, możemy spróbować rozwiązać podstawowy problem uczenia maszynowego - regresję liniową.

# %%
random.seed(10)
sample_data = pd.DataFrame({
    'x': np.random.uniform(-3, 3, 50)
})
sample_data["y"] = sample_data.x + np.random.normal(3, 1.2, 50)
sample_data["intercept"] = 1

# %%
sample_data.plot(x = 'x', y = 'y', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# Naszym zadaniem jest znalezienie parametrów `b0` i `b1` modelu liniowego `y = b0 + b1*x` takich aby błąd średniokwadratowy (mean squared error) był minimalny. Zanim zaczniemy, sprawdźmy rozwiązanie z pythona:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X = np.array(sample_data["x"]).reshape(-1, 1)
y = np.array(sample_data["y"]).reshape(-1, 1)

reg = LinearRegression().fit(X, y)
print("b0", reg.intercept_)
print("b1", reg.coef_)
print("MSE:", mean_squared_error(y, reg.predict(X)))
# Out:
# b0 [3.29458697]
# b1 [[0.81885152]]
# MSE: 1.3897612003703324

# %%
X = np.concatenate((np.array(sample_data["intercept"]).reshape(-1, 1), X), axis=1)

# %% [markdown]
# Teraz musimy zaimplementować MSE:

# %%
def MSE(beta, X, y):
    betaX = np.matmul(beta, X.transpose())
    return np.mean((betaX - y[:,0])**2)

# %%
MSE(np.array([3.17105624, 1.16753532]), X, y)
# Out:
# 1.7765997652961472

# %% [markdown]
# oraz pochodną MSE:

# %%
def MSE_grad(beta, X, y):
    betaX = np.matmul(beta, X.transpose())
    return 2*np.matmul(betaX - y[:,0], X)/y.shape[0]

# %% [markdown]
# Szczerze mówiąc, nie musimy tutaj używać Gradient Descent, równanie `MSE_grad == 0` ma rozwiązanie numeryczne:

# %%
np.matmul(np.matmul(np.linalg.inv(np.matmul(X.transpose(), X)), X.transpose()), y[:,0])
# Out:
# array([3.29458697, 0.81885152])

# %% [markdown]
# Ale powiedzmy, że naprawdę chcemy:

# %%
beta00 = np.array([5, -0.2])
lr = 0.1
epochs = 30 # Liczba epok, czyli liczba aktualizacji wag (po całym datasecie)

def GD_linear_regression(beta00, X, y, lr, epochs):
    beta = beta00
    results = pd.DataFrame({
        'b0': [beta00[0]],
        'b1': [beta00[1]],
        'mse': [MSE(beta00, X, y)],
        'epoch': [0]
    })
    for i in range(1, epochs + 1):
        beta = beta - lr * MSE_grad(beta, X, y) # Gradient Descent
        print("Updated b0 value:", round(beta[0], 8), ". Updated b1 value:", round(beta[1], 8), ". Updated MSE value:", round(MSE(beta, X, y), 8))
        results = results.append(pd.DataFrame({
            'b0': [beta[0]],
            'b1': [beta[1]],
            'mse': [MSE(beta, X, y)],
            'epoch': [i]
    }))
    return results

task2 = GD_linear_regression(beta00, X, y, lr, epochs)
# Out:
# Updated b0 value: 4.64451076 . Updated b1 value: 0.4366775 . Updated MSE value: 3.72407318
# Updated b0 value: 4.36912203 . Updated b1 value: 0.68553954 . Updated MSE value: 2.61806768
# Updated b0 value: 4.15232998 . Updated b1 value: 0.78088454 . Updated MSE value: 2.13442245
# Updated b0 value: 3.98024452 . Updated b1 value: 0.81583993 . Updated MSE value: 1.86020673
# Updated b0 value: 3.84307043 . Updated b1 value: 0.82734583 . Updated MSE value: 1.69015342
# Updated b0 value: 3.73349384 . Updated b1 value: 0.8299944 . Updated MSE value: 1.58208215
# Updated b0 value: 3.64587003 . Updated b1 value: 0.82950115 . Updated MSE value: 1.51297295
# Updated b0 value: 3.575764 . Updated b1 value: 0.82806546 . Updated MSE value: 1.4687106
# Updated b0 value: 3.51965888 . Updated b1 value: 0.82650164 . Updated MSE value: 1.44035103
# Updated b0 value: 3.47475267 . Updated b1 value: 0.8250847 . Updated MSE value: 1.42217888
# Updated b0 value: 3.43880767 . Updated b1 value: 0.82388469 . Updated MSE value: 1.41053432
# Updated b0 value: 3.4100347 . Updated b1 value: 0.82289789 . Updated MSE value: 1.40307254
# Updated b0 value: 3.38700237 . Updated b1 value: 0.82209754 . Updated MSE value: 1.39829106
# Updated b0 value: 3.36856519 . Updated b1 value: 0.8214527 . Updated MSE value: 1.39522711
# Updated b0 value: 3.35380632 . Updated b1 value: 0.82093485 . Updated MSE value: 1.39326373
# Updated b0 value: 3.34199191 . Updated b1 value: 0.82051966 . Updated MSE value: 1.39200561
# Updated b0 value: 3.33253451 . Updated b1 value: 0.82018703 . Updated MSE value: 1.39119941
# Updated b0 value: 3.32496388 . Updated b1 value: 0.81992067 . Updated MSE value: 1.3906828
# Updated b0 value: 3.31890362 . Updated b1 value: 0.8197074 . Updated MSE value: 1.39035176
# Updated b0 value: 3.31405239 . Updated b1 value: 0.81953666 . Updated MSE value: 1.39013963
# Updated b0 value: 3.31016899 . Updated b1 value: 0.81939998 . Updated MSE value: 1.3900037
# Updated b0 value: 3.30706034 . Updated b1 value: 0.81929056 . Updated MSE value: 1.38991659
# Updated b0 value: 3.30457188 . Updated b1 value: 0.81920297 . Updated MSE value: 1.38986077
# Updated b0 value: 3.30257986 . Updated b1 value: 0.81913286 . Updated MSE value: 1.38982501
# Updated b0 value: 3.30098526 . Updated b1 value: 0.81907673 . Updated MSE value: 1.38980209
# Updated b0 value: 3.29970879 . Updated b1 value: 0.8190318 . Updated MSE value: 1.3897874
# Updated b0 value: 3.29868697 . Updated b1 value: 0.81899583 . Updated MSE value: 1.38977799
# Updated b0 value: 3.29786901 . Updated b1 value: 0.81896704 . Updated MSE value: 1.38977196
# Updated b0 value: 3.29721424 . Updated b1 value: 0.81894399 . Updated MSE value: 1.38976809
# Updated b0 value: 3.29669009 . Updated b1 value: 0.81892555 . Updated MSE value: 1.38976562
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/2877991270.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({

# %%
prediction = pd.DataFrame({
    'x': sample_data.x
})
prediction["start"] = [beta00[0] + beta00[1]*x for x in prediction.x]
prediction["end"] = [task2.b0.iloc[-1] + task2.b1.iloc[-1]*x for x in prediction.x]
ax = sample_data.plot(x = 'x', y = 'y', kind = 'scatter')
prediction.plot(ax = ax, x = 'x')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
task2.plot(x = 'epoch', y = 'mse')
# Out:
# <AxesSubplot:xlabel='epoch'>

# %%
import itertools
beta_grid = list(itertools.product(np.arange(task2.b0.iloc[-1]-2, task2.b0.iloc[-1] +2, 0.1),
           np.arange(task2.b1.iloc[-1]-2, task2.b1.iloc[-1] +2, 0.1)))
beta_grid = pd.DataFrame({
    'b0': [x[0] for x in beta_grid],
    'b1': [x[1] for x in beta_grid]
})
beta_grid["mse"] = [MSE(np.array([b0, b1]), X, y) for b0, b1 in zip(beta_grid.b0, beta_grid.b1)]

# %%
import seaborn as sns
sns.heatmap(beta_grid.pivot('b0', 'b1', 'mse'), square=False)
# Out:
# /tmp/ipykernel_5040/3618656048.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(beta_grid.pivot('b0', 'b1', 'mse'), square=False)
# <AxesSubplot:xlabel='b1', ylabel='b0'>

# %%
task2.plot(x = 'b1', y = 'b0', marker = ">")
# Out:
# <AxesSubplot:xlabel='b1'>

# %% [markdown]
# Wiemy teraz, czym jest Gradient Descent i jak go używać do rozwiązywania problemów ML. W rzeczywistości często będziemy używać zaawansowanej wersji gradientu o nazwie **Stochastic Gradient Descent** lub **SGD** w skrócie. Wprowadzimy jedną małą zmianę w naszym algorytmie. Jak pamiętasz, nasz gradient MSE `MSE_grad` bierze pod uwagę macierz obliczeń `X` i vecotr `y` i mnoży je na różne sposoby. Załóżmy na chwilę, że mamy miliony obserwacji, te mnożenia mogą zająć dużo czasu i pamięci, może być nawet niemożliwe. Istnieje proste rozwiązanie tego problemu. Nasze dane możemy podzielić na tzw. **batche**. Jeśli mamy np. 50 obserwacji, możemy je podzielić na 5 batchy - po 10 obserwacji każda. Po tych 5 batchach SGD zobaczy wszystkie obserwacje, które mieliśmy - minie pierwsza **epoka** i proces rozpocznie się od początku. Można o tym myśleć jako o dodatkowej pętli nad partiami wewnątrz pętli epok z implementacji GD.

# %%
beta00 = np.array([5, -0.2])
lr = 0.1
epochs = 30 # Liczba epok, czyli liczba aktualizacji wag (po całym datasecie)
batch_size = 1 # Liczba podzbiorów w datasecie

def SGD_linear_regression(beta00, X, y, lr, epochs, batch_size):
    beta = beta00
    results = pd.DataFrame({
        'b0': [beta00[0]],
        'b1': [beta00[1]],
        'mse': [MSE(beta00, X, y)],
        'epoch': [0]
    })
    batches_per_epoch = int(np.ceil(y.shape[0] / batch_size))
    for i in range(1, epochs + 1):
        for b in range(1, batches_per_epoch + 1):
            X_b = X[((b - 1) * batch_size ):min((b * batch_size + 1), y.shape[0]), :]
            y_b = y[((b - 1) * batch_size ):min((b * batch_size + 1), y.shape[0]), :]
            beta = beta - lr * MSE_grad(beta, X_b, y_b) # Stochastic Gradient Descent
            print("Updated b0 value:", round(beta[0], 8), ". Updated b1 value:", round(beta[1], 8), ". Updated MSE value:", round(MSE(beta, X, y), 8))
            results = results.append(pd.DataFrame({
                'b0': [beta[0]],
                'b1': [beta[1]],
                'mse': [MSE(beta, X, y)],
                'epoch': [i + b / batches_per_epoch]
    }))
    return results

task3 = SGD_linear_regression(beta00, X, y, lr, epochs, batch_size)
# Out:
# Updated b0 value: 4.65405932 . Updated b1 value: 0.37421181 . Updated MSE value: 3.9177276
# Updated b0 value: 4.78600347 . Updated b1 value: 0.57247902 . Updated MSE value: 3.84851239
# Updated b0 value: 4.99724202 . Updated b1 value: 0.93575404 . Updated MSE value: 4.30173293
# Updated b0 value: 4.7837072 . Updated b1 value: 1.81916825 . Updated MSE value: 6.40465929
# Updated b0 value: 4.80360676 . Updated b1 value: 1.82066806 . Updated MSE value: 6.47021316
# Updated b0 value: 5.07653414 . Updated b1 value: 1.14193661 . Updated MSE value: 4.79748287
# Updated b0 value: 4.90400111 . Updated b1 value: 1.58259194 . Updated MSE value: 5.55965087
# Updated b0 value: 4.88279024 . Updated b1 value: 1.65740881 . Updated MSE value: 5.83768863
# Updated b0 value: 4.74253545 . Updated b1 value: 0.88761637 . Updated MSE value: 3.4864519
# Updated b0 value: 4.49125391 . Updated b1 value: 0.6695614 . Updated MSE value: 2.91403383
# Updated b0 value: 4.19014414 . Updated b1 value: 0.39416182 . Updated MSE value: 2.78775546
# Updated b0 value: 3.97005566 . Updated b1 value: 0.55218944 . Updated MSE value: 2.0852514
# Updated b0 value: 3.53422782 . Updated b1 value: 1.39560846 . Updated MSE value: 2.42763474
# Updated b0 value: 3.3524191 . Updated b1 value: 1.43063794 . Updated MSE value: 2.51325026
# Updated b0 value: 2.99160452 . Updated b1 value: 0.82622672 . Updated MSE value: 1.48203905
# Updated b0 value: 2.96755892 . Updated b1 value: 0.77087834 . Updated MSE value: 1.50140859
# Updated b0 value: 3.21769987 . Updated b1 value: 1.08018534 . Updated MSE value: 1.60381972
# Updated b0 value: 3.56259696 . Updated b1 value: 0.75898505 . Updated MSE value: 1.47463331
# Updated b0 value: 3.84784711 . Updated b1 value: -0.01568374 . Updated MSE value: 3.854771
# Updated b0 value: 3.90937774 . Updated b1 value: 0.09008216 . Updated MSE value: 3.42765954
# Updated b0 value: 3.59969746 . Updated b1 value: 1.19938606 . Updated MSE value: 1.90174554
# Updated b0 value: 3.39517803 . Updated b1 value: 0.94275293 . Updated MSE value: 1.44426643
# Updated b0 value: 3.17860021 . Updated b1 value: 0.69135787 . Updated MSE value: 1.44998691
# Updated b0 value: 3.23100533 . Updated b1 value: 0.52746869 . Updated MSE value: 1.64641764
# Updated b0 value: 3.24550484 . Updated b1 value: 0.60204094 . Updated MSE value: 1.53197482
# Updated b0 value: 3.17395742 . Updated b1 value: 0.7510011 . Updated MSE value: 1.41699468
# Updated b0 value: 3.29088146 . Updated b1 value: 0.65772945 . Updated MSE value: 1.46773097
# Updated b0 value: 3.19173772 . Updated b1 value: 0.85133196 . Updated MSE value: 1.40398295
# Updated b0 value: 3.05214736 . Updated b1 value: 0.98692154 . Updated MSE value: 1.53921594
# Updated b0 value: 2.90935527 . Updated b1 value: 0.76843028 . Updated MSE value: 1.54306064
# Updated b0 value: 3.00391577 . Updated b1 value: 0.71574063 . Updated MSE value: 1.50197386
# Updated b0 value: 3.30937023 . Updated b1 value: 0.7267792 . Updated MSE value: 1.41565623
# Updated b0 value: 3.4303091 . Updated b1 value: 0.7189872 . Updated MSE value: 1.44007813
# Updated b0 value: 3.4014534 . Updated b1 value: 0.76156877 . Updated MSE value: 1.41191133
# Updated b0 value: 3.39834883 . Updated b1 value: 0.75045714 . Updated MSE value: 1.41559332
# Updated b0 value: 3.34393182 . Updated b1 value: 0.75387458 . Updated MSE value: 1.40534143
# Updated b0 value: 3.30953669 . Updated b1 value: 0.76241563 . Updated MSE value: 1.39967859
# Updated b0 value: 3.2040584 . Updated b1 value: 0.83617921 . Updated MSE value: 1.39908102
# Updated b0 value: 2.82917532 . Updated b1 value: 0.8813695 . Updated MSE value: 1.62223299
# Updated b0 value: 2.59567158 . Updated b1 value: 0.87123387 . Updated MSE value: 1.8916693
# Updated b0 value: 2.70538471 . Updated b1 value: 1.00611275 . Updated MSE value: 1.85793767
# Updated b0 value: 2.80875325 . Updated b1 value: 1.15464499 . Updated MSE value: 1.9878282
# Updated b0 value: 3.05306471 . Updated b1 value: 0.64440219 . Updated MSE value: 1.53362119
# Updated b0 value: 3.04938581 . Updated b1 value: 0.23066961 . Updated MSE value: 2.46949098
# Updated b0 value: 2.82932652 . Updated b1 value: 0.42655629 . Updated MSE value: 2.04305224
# Updated b0 value: 2.81153312 . Updated b1 value: 0.87010788 . Updated MSE value: 1.63450103
# Updated b0 value: 2.78842921 . Updated b1 value: 0.76671114 . Updated MSE value: 1.65039769
# Updated b0 value: 2.85440399 . Updated b1 value: 0.82873651 . Updated MSE value: 1.58443126
# Updated b0 value: 2.73245757 . Updated b1 value: 0.75591966 . Updated MSE value: 1.71265407
# Updated b0 value: 2.467809 . Updated b1 value: 0.57252692 . Updated MSE value: 2.22692615
# Updated b0 value: 2.75957874 . Updated b1 value: 0.48643789 . Updated MSE value: 1.98302307
# Updated b0 value: 3.2502734 . Updated b1 value: 0.98965389 . Updated MSE value: 1.48049472
# Updated b0 value: 3.62399972 . Updated b1 value: 1.63454408 . Updated MSE value: 3.46043053
# Updated b0 value: 3.76046726 . Updated b1 value: 1.62941925 . Updated MSE value: 3.5285056
# Updated b0 value: 3.91364533 . Updated b1 value: 1.41075688 . Updated MSE value: 2.77439023
# Updated b0 value: 4.21472096 . Updated b1 value: 0.73889378 . Updated MSE value: 2.26602988
# Updated b0 value: 4.00316559 . Updated b1 value: 1.28207186 . Updated MSE value: 2.49047075
# Updated b0 value: 4.01845866 . Updated b1 value: 1.27165528 . Updated MSE value: 2.48375768
# Updated b0 value: 4.07530418 . Updated b1 value: 1.05411588 . Updated MSE value: 2.13969681
# Updated b0 value: 3.89360203 . Updated b1 value: 0.94149427 . Updated MSE value: 1.7834084
# Updated b0 value: 3.66657 . Updated b1 value: 0.72652364 . Updated MSE value: 1.55861459
# Updated b0 value: 3.56004731 . Updated b1 value: 0.82647057 . Updated MSE value: 1.46011891
# Updated b0 value: 3.29985529 . Updated b1 value: 1.33758595 . Updated MSE value: 2.19831198
# Updated b0 value: 3.15205821 . Updated b1 value: 1.35664218 . Updated MSE value: 2.2903474
# Updated b0 value: 2.85185577 . Updated b1 value: 0.85518734 . Updated MSE value: 1.59201582
# Updated b0 value: 2.8401329 . Updated b1 value: 0.83289353 . Updated MSE value: 1.59778478
# Updated b0 value: 3.09175186 . Updated b1 value: 1.1339993 . Updated MSE value: 1.7385066
# Updated b0 value: 3.47067741 . Updated b1 value: 0.74949846 . Updated MSE value: 1.43695498
# Updated b0 value: 3.76921425 . Updated b1 value: -0.0608603 . Updated MSE value: 4.00050538
# Updated b0 value: 3.83704732 . Updated b1 value: 0.06433297 . Updated MSE value: 3.45329164
# Updated b0 value: 3.5362505 . Updated b1 value: 1.17955173 . Updated MSE value: 1.82695011
# Updated b0 value: 3.34289816 . Updated b1 value: 0.9422053 . Updated MSE value: 1.43699446
# Updated b0 value: 3.13691206 . Updated b1 value: 0.70401023 . Updated MSE value: 1.45170875
# Updated b0 value: 3.19827647 . Updated b1 value: 0.53678226 . Updated MSE value: 1.63437362
# Updated b0 value: 3.22181477 . Updated b1 value: 0.59892517 . Updated MSE value: 1.5381939
# Updated b0 value: 3.15425231 . Updated b1 value: 0.74325961 . Updated MSE value: 1.42513253
# Updated b0 value: 3.2739395 . Updated b1 value: 0.64790275 . Updated MSE value: 1.47753841
# Updated b0 value: 3.17581555 . Updated b1 value: 0.8405035 . Updated MSE value: 1.40564079
# Updated b0 value: 3.04021888 . Updated b1 value: 0.98555995 . Updated MSE value: 1.54400632
# Updated b0 value: 2.90029533 . Updated b1 value: 0.77222844 . Updated MSE value: 1.5491622
# Updated b0 value: 2.99612797 . Updated b1 value: 0.72021891 . Updated MSE value: 1.50392139
# Updated b0 value: 3.30310489 . Updated b1 value: 0.73130234 . Updated MSE value: 1.41298087
# Updated b0 value: 3.42565233 . Updated b1 value: 0.72279481 . Updated MSE value: 1.43645689
# Updated b0 value: 3.39901866 . Updated b1 value: 0.76085144 . Updated MSE value: 1.41163635
# Updated b0 value: 3.39624004 . Updated b1 value: 0.74972802 . Updated MSE value: 1.41545164
# Updated b0 value: 3.34226881 . Updated b1 value: 0.75323066 . Updated MSE value: 1.40542194
# Updated b0 value: 3.30822225 . Updated b1 value: 0.76182254 . Updated MSE value: 1.39983397
# Updated b0 value: 3.20299373 . Updated b1 value: 0.83558557 . Updated MSE value: 1.39920905
# Updated b0 value: 2.82829201 . Updated b1 value: 0.88073996 . Updated MSE value: 1.62278683
# Updated b0 value: 2.59512032 . Updated b1 value: 0.87118873 . Updated MSE value: 1.89242559
# Updated b0 value: 2.70495838 . Updated b1 value: 1.00627644 . Updated MSE value: 1.85864954
# Updated b0 value: 2.80836125 . Updated b1 value: 1.15484539 . Updated MSE value: 1.98864636
# Updated b0 value: 3.05274711 . Updated b1 value: 0.6444212 . Updated MSE value: 1.53374758
# Updated b0 value: 3.04913287 . Updated b1 value: 0.23065735 . Updated MSE value: 2.46963696
# Updated b0 value: 2.82912386 . Updated b1 value: 0.42654391 . Updated MSE value: 2.04325803
# Updated b0 value: 2.81137246 . Updated b1 value: 0.87013392 . Updated MSE value: 1.63466724
# Updated b0 value: 2.78829139 . Updated b1 value: 0.76677122 . Updated MSE value: 1.65052169
# Updated b0 value: 2.85428313 . Updated b1 value: 0.82881089 . Updated MSE value: 1.5845469
# Updated b0 value: 2.73234743 . Updated b1 value: 0.75600307 . Updated MSE value: 1.71275202
# Updated b0 value: 2.46770933 . Updated b1 value: 0.57261758 . Updated MSE value: 2.22696386
# Updated b0 value: 2.75951441 . Updated b1 value: 0.48648463 . Updated MSE value: 1.98299903
# Updated b0 value: 3.25021354 . Updated b1 value: 0.98969754 . Updated MSE value: 1.48054658
# Updated b0 value: 3.6239367 . Updated b1 value: 1.63458223 . Updated MSE value: 3.46058162
# Updated b0 value: 3.76042095 . Updated b1 value: 1.62941018 . Updated MSE value: 3.52842416
# Updated b0 value: 3.91360488 . Updated b1 value: 1.41073827 . Updated MSE value: 2.77427892
# Updated b0 value: 4.2146818 . Updated b1 value: 0.73887546 . Updated MSE value: 2.26596855
# Updated b0 value: 4.00312465 . Updated b1 value: 1.28205821 . Updated MSE value: 2.49037875
# Updated b0 value: 4.01841938 . Updated b1 value: 1.27163775 . Updated MSE value: 2.4836574
# Updated b0 value: 4.07527385 . Updated b1 value: 1.05412345 . Updated MSE value: 2.13966034
# Updated b0 value: 3.89357487 . Updated b1 value: 0.94150663 . Updated MSE value: 1.7833844
# Updated b0 value: 3.6665462 . Updated b1 value: 0.72653874 . Updated MSE value: 1.55858739
# Updated b0 value: 3.56002868 . Updated b1 value: 0.82648304 . Updated MSE value: 1.46010914
# Updated b0 value: 3.29984464 . Updated b1 value: 1.33758331 . Updated MSE value: 2.19830442
# Updated b0 value: 3.1520491 . Updated b1 value: 1.35663882 . Updated MSE value: 2.29033975
# Updated b0 value: 2.85184941 . Updated b1 value: 0.85518866 . Updated MSE value: 1.59202184
# Updated b0 value: 2.84012711 . Updated b1 value: 0.83289635 . Updated MSE value: 1.59779048
# Updated b0 value: 3.09174614 . Updated b1 value: 1.13400174 . Updated MSE value: 1.73851388
# Updated b0 value: 3.47067323 . Updated b1 value: 0.74949803 . Updated MSE value: 1.43695366
# Updated b0 value: 3.76921067 . Updated b1 value: -0.06086236 . Updated MSE value: 4.00051254
# Updated b0 value: 3.83704403 . Updated b1 value: 0.0643318 . Updated MSE value: 3.45329312
# Updated b0 value: 3.53624761 . Updated b1 value: 1.17955083 . Updated MSE value: 1.82694694
# Updated b0 value: 3.34289578 . Updated b1 value: 0.94220527 . Updated MSE value: 1.43699426
# Updated b0 value: 3.13691016 . Updated b1 value: 0.7040108 . Updated MSE value: 1.45170893
# Updated b0 value: 3.19827498 . Updated b1 value: 0.53678268 . Updated MSE value: 1.63437313
# Updated b0 value: 3.22181369 . Updated b1 value: 0.59892503 . Updated MSE value: 1.53819421
# Updated b0 value: 3.15425141 . Updated b1 value: 0.74325925 . Updated MSE value: 1.42513293
# Updated b0 value: 3.27393873 . Updated b1 value: 0.64790231 . Updated MSE value: 1.47753888
# Updated b0 value: 3.17581483 . Updated b1 value: 0.84050301 . Updated MSE value: 1.40564089
# Updated b0 value: 3.04021833 . Updated b1 value: 0.98555989 . Updated MSE value: 1.54400655
# Updated b0 value: 2.90029491 . Updated b1 value: 0.77222862 . Updated MSE value: 1.54916249
# Updated b0 value: 2.99612762 . Updated b1 value: 0.72021911 . Updated MSE value: 1.50392149
# Updated b0 value: 3.30310461 . Updated b1 value: 0.73130254 . Updated MSE value: 1.41298075
# Updated b0 value: 3.42565211 . Updated b1 value: 0.72279498 . Updated MSE value: 1.43645672
# Updated b0 value: 3.39901855 . Updated b1 value: 0.76085141 . Updated MSE value: 1.41163633
# Updated b0 value: 3.39623994 . Updated b1 value: 0.74972799 . Updated MSE value: 1.41545164
# Updated b0 value: 3.34226873 . Updated b1 value: 0.75323063 . Updated MSE value: 1.40542194
# Updated b0 value: 3.30822219 . Updated b1 value: 0.76182251 . Updated MSE value: 1.39983398
# Updated b0 value: 3.20299369 . Updated b1 value: 0.83558554 . Updated MSE value: 1.39920906
# Updated b0 value: 2.82829197 . Updated b1 value: 0.88073993 . Updated MSE value: 1.62278685
# Updated b0 value: 2.59512029 . Updated b1 value: 0.87118873 . Updated MSE value: 1.89242563
# Updated b0 value: 2.70495836 . Updated b1 value: 1.00627645 . Updated MSE value: 1.85864957
# Updated b0 value: 2.80836123 . Updated b1 value: 1.1548454 . Updated MSE value: 1.98864639
# Updated b0 value: 3.05274709 . Updated b1 value: 0.6444212 . Updated MSE value: 1.53374759
# Updated b0 value: 3.04913286 . Updated b1 value: 0.23065735 . Updated MSE value: 2.46963696
# Updated b0 value: 2.82912385 . Updated b1 value: 0.42654391 . Updated MSE value: 2.04325804
# Updated b0 value: 2.81137245 . Updated b1 value: 0.87013392 . Updated MSE value: 1.63466724
# Updated b0 value: 2.78829139 . Updated b1 value: 0.76677122 . Updated MSE value: 1.65052169
# Updated b0 value: 2.85428313 . Updated b1 value: 0.82881089 . Updated MSE value: 1.58454691
# Updated b0 value: 2.73234743 . Updated b1 value: 0.75600307 . Updated MSE value: 1.71275203
# Updated b0 value: 2.46770932 . Updated b1 value: 0.57261758 . Updated MSE value: 2.22696386
# Updated b0 value: 2.7595144 . Updated b1 value: 0.48648463 . Updated MSE value: 1.98299903
# Updated b0 value: 3.25021354 . Updated b1 value: 0.98969754 . Updated MSE value: 1.48054658
# Updated b0 value: 3.62393669 . Updated b1 value: 1.63458223 . Updated MSE value: 3.46058162
# Updated b0 value: 3.76042095 . Updated b1 value: 1.62941018 . Updated MSE value: 3.52842416
# Updated b0 value: 3.91360488 . Updated b1 value: 1.41073827 . Updated MSE value: 2.77427892
# Updated b0 value: 4.21468179 . Updated b1 value: 0.73887546 . Updated MSE value: 2.26596855
# Updated b0 value: 4.00312465 . Updated b1 value: 1.2820582 . Updated MSE value: 2.49037875
# Updated b0 value: 4.01841938 . Updated b1 value: 1.27163775 . Updated MSE value: 2.48365739
# Updated b0 value: 4.07527385 . Updated b1 value: 1.05412345 . Updated MSE value: 2.13966034
# Updated b0 value: 3.89357487 . Updated b1 value: 0.94150663 . Updated MSE value: 1.7833844
# Updated b0 value: 3.6665462 . Updated b1 value: 0.72653874 . Updated MSE value: 1.55858739
# Updated b0 value: 3.56002867 . Updated b1 value: 0.82648304 . Updated MSE value: 1.46010914
# Updated b0 value: 3.29984464 . Updated b1 value: 1.33758331 . Updated MSE value: 2.19830442
# Updated b0 value: 3.1520491 . Updated b1 value: 1.35663882 . Updated MSE value: 2.29033975
# Updated b0 value: 2.85184941 . Updated b1 value: 0.85518866 . Updated MSE value: 1.59202185
# Updated b0 value: 2.84012711 . Updated b1 value: 0.83289635 . Updated MSE value: 1.59779048
# Updated b0 value: 3.09174614 . Updated b1 value: 1.13400174 . Updated MSE value: 1.73851388
# Updated b0 value: 3.47067323 . Updated b1 value: 0.74949803 . Updated MSE value: 1.43695366
# Updated b0 value: 3.76921067 . Updated b1 value: -0.06086236 . Updated MSE value: 4.00051254
# Updated b0 value: 3.83704403 . Updated b1 value: 0.0643318 . Updated MSE value: 3.45329312
# Updated b0 value: 3.53624761 . Updated b1 value: 1.17955083 . Updated MSE value: 1.82694694
# Updated b0 value: 3.34289578 . Updated b1 value: 0.94220527 . Updated MSE value: 1.43699426
# Updated b0 value: 3.13691016 . Updated b1 value: 0.7040108 . Updated MSE value: 1.45170893
# Updated b0 value: 3.19827498 . Updated b1 value: 0.53678268 . Updated MSE value: 1.63437313
# Updated b0 value: 3.22181369 . Updated b1 value: 0.59892503 . Updated MSE value: 1.53819421
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# ...
#   results = results.append(pd.DataFrame({
# 0.7040108 . Updated MSE value: 1.45170893
# Updated b0 value: 3.19827498 . Updated b1 value: 0.53678268 . Updated MSE value: 1.63437313
# Updated b0 value: 3.22181369 . Updated b1 value: 0.59892503 . Updated MSE value: 1.53819421
# Updated b0 value: 3.15425141 . Updated b1 value: 0.74325925 . Updated MSE value: 1.42513293
# Updated b0 value: 3.27393873 . Updated b1 value: 0.64790231 . Updated MSE value: 1.47753888
# Updated b0 value: 3.17581483 . Updated b1 value: 0.84050301 . Updated MSE value: 1.40564089
# Updated b0 value: 3.04021833 . Updated b1 value: 0.98555989 . Updated MSE value: 1.54400655
# Updated b0 value: 2.90029491 . Updated b1 value: 0.77222862 . Updated MSE value: 1.54916249
# Updated b0 value: 2.99612762 . Updated b1 value: 0.72021911 . Updated MSE value: 1.50392149
# Updated b0 value: 3.30310461 . Updated b1 value: 0.73130254 . Updated MSE value: 1.41298075
# Updated b0 value: 3.42565211 . Updated b1 value: 0.72279498 . Updated MSE value: 1.43645672
# Updated b0 value: 3.39901855 . Updated b1 value: 0.76085141 . Updated MSE value: 1.41163633
# Updated b0 value: 3.39623994 . Updated b1 value: 0.74972799 . Updated MSE value: 1.41545164
# Updated b0 value: 3.34226873 . Updated b1 value: 0.75323063 . Updated MSE value: 1.40542194
# Updated b0 value: 3.30822219 . Updated b1 value: 0.76182251 . Updated MSE value: 1.39983398
# Updated b0 value: 3.20299369 . Updated b1 value: 0.83558554 . Updated MSE value: 1.39920906
# Updated b0 value: 2.82829197 . Updated b1 value: 0.88073993 . Updated MSE value: 1.62278685
# Updated b0 value: 2.59512029 . Updated b1 value: 0.87118873 . Updated MSE value: 1.89242563
# Updated b0 value: 2.70495836 . Updated b1 value: 1.00627645 . Updated MSE value: 1.85864957
# Updated b0 value: 2.80836123 . Updated b1 value: 1.1548454 . Updated MSE value: 1.98864639
# Updated b0 value: 3.05274709 . Updated b1 value: 0.6444212 . Updated MSE value: 1.53374759
# Updated b0 value: 3.04913286 . Updated b1 value: 0.23065735 . Updated MSE value: 2.46963696
# Updated b0 value: 2.82912385 . Updated b1 value: 0.42654391 . Updated MSE value: 2.04325804
# Updated b0 value: 2.81137245 . Updated b1 value: 0.87013392 . Updated MSE value: 1.63466724
# Updated b0 value: 2.78829139 . Updated b1 value: 0.76677122 . Updated MSE value: 1.65052169
# Updated b0 value: 2.85428313 . Updated b1 value: 0.82881089 . Updated MSE value: 1.58454691
# Updated b0 value: 2.73234743 . Updated b1 value: 0.75600307 . Updated MSE value: 1.71275203
# Updated b0 value: 2.46770932 . Updated b1 value: 0.57261758 . Updated MSE value: 2.22696386
# Updated b0 value: 2.7595144 . Updated b1 value: 0.48648463 . Updated MSE value: 1.98299903
# Updated b0 value: 3.25021354 . Updated b1 value: 0.98969754 . Updated MSE value: 1.48054658
# Updated b0 value: 3.62393669 . Updated b1 value: 1.63458223 . Updated MSE value: 3.46058162
# Updated b0 value: 3.76042095 . Updated b1 value: 1.62941018 . Updated MSE value: 3.52842416
# Updated b0 value: 3.91360488 . Updated b1 value: 1.41073827 . Updated MSE value: 2.77427892
# Updated b0 value: 4.21468179 . Updated b1 value: 0.73887546 . Updated MSE value: 2.26596855
# Updated b0 value: 4.00312465 . Updated b1 value: 1.2820582 . Updated MSE value: 2.49037875
# Updated b0 value: 4.01841938 . Updated b1 value: 1.27163775 . Updated MSE value: 2.48365739
# Updated b0 value: 4.07527385 . Updated b1 value: 1.05412345 . Updated MSE value: 2.13966034
# Updated b0 value: 3.89357487 . Updated b1 value: 0.94150663 . Updated MSE value: 1.7833844
# Updated b0 value: 3.6665462 . Updated b1 value: 0.72653874 . Updated MSE value: 1.55858739
# Updated b0 value: 3.56002867 . Updated b1 value: 0.82648304 . Updated MSE value: 1.46010914
# Updated b0 value: 3.29984464 . Updated b1 value: 1.33758331 . Updated MSE value: 2.19830442
# Updated b0 value: 3.1520491 . Updated b1 value: 1.35663882 . Updated MSE value: 2.29033975
# Updated b0 value: 2.85184941 . Updated b1 value: 0.85518866 . Updated MSE value: 1.59202185
# Updated b0 value: 2.84012711 . Updated b1 value: 0.83289635 . Updated MSE value: 1.59779048
# Updated b0 value: 3.09174614 . Updated b1 value: 1.13400174 . Updated MSE value: 1.73851388
# Updated b0 value: 3.47067323 . Updated b1 value: 0.74949803 . Updated MSE value: 1.43695366
# Updated b0 value: 3.76921067 . Updated b1 value: -0.06086236 . Updated MSE value: 4.00051254
# Updated b0 value: 3.83704403 . Updated b1 value: 0.0643318 . Updated MSE value: 3.45329312
# Updated b0 value: 3.53624761 . Updated b1 value: 1.17955083 . Updated MSE value: 1.82694694
# Updated b0 value: 3.34289578 . Updated b1 value: 0.94220527 . Updated MSE value: 1.43699426
# Updated b0 value: 3.13691016 . Updated b1 value: 0.7040108 . Updated MSE value: 1.45170893
# Updated b0 value: 3.19827498 . Updated b1 value: 0.53678268 . Updated MSE value: 1.63437313
# Updated b0 value: 3.22181369 . Updated b1 value: 0.59892503 . Updated MSE value: 1.53819421
# Updated b0 value: 3.15425141 . Updated b1 value: 0.74325925 . Updated MSE value: 1.42513293
# Updated b0 value: 3.27393873 . Updated b1 value: 0.64790231 . Updated MSE value: 1.47753888
# Updated b0 value: 3.17581483 . Updated b1 value: 0.84050301 . Updated MSE value: 1.40564089
# Updated b0 value: 3.04021833 . Updated b1 value: 0.98555989 . Updated MSE value: 1.54400655
# Updated b0 value: 2.90029491 . Updated b1 value: 0.77222862 . Updated MSE value: 1.54916249
# Updated b0 value: 2.99612762 . Updated b1 value: 0.72021911 . Updated MSE value: 1.50392149
# Updated b0 value: 3.30310461 . Updated b1 value: 0.73130254 . Updated MSE value: 1.41298075
# Updated b0 value: 3.42565211 . Updated b1 value: 0.72279498 . Updated MSE value: 1.43645672
# Updated b0 value: 3.39901855 . Updated b1 value: 0.76085141 . Updated MSE value: 1.41163633
# Updated b0 value: 3.39623994 . Updated b1 value: 0.74972799 . Updated MSE value: 1.41545164
# Updated b0 value: 3.34226873 . Updated b1 value: 0.75323063 . Updated MSE value: 1.40542194
# Updated b0 value: 3.30822219 . Updated b1 value: 0.76182251 . Updated MSE value: 1.39983398
# Updated b0 value: 3.20299369 . Updated b1 value: 0.83558554 . Updated MSE value: 1.39920906
# Updated b0 value: 2.82829197 . Updated b1 value: 0.88073993 . Updated MSE value: 1.62278685
# Updated b0 value: 2.59512029 . Updated b1 value: 0.87118873 . Updated MSE value: 1.89242563
# Updated b0 value: 2.70495836 . Updated b1 value: 1.00627645 . Updated MSE value: 1.85864957
# Updated b0 value: 2.80836123 . Updated b1 value: 1.1548454 . Updated MSE value: 1.98864639
# Updated b0 value: 3.05274709 . Updated b1 value: 0.6444212 . Updated MSE value: 1.53374759
# Updated b0 value: 3.04913286 . Updated b1 value: 0.23065735 . Updated MSE value: 2.46963696
# Updated b0 value: 2.82912385 . Updated b1 value: 0.42654391 . Updated MSE value: 2.04325804
# Updated b0 value: 2.81137245 . Updated b1 value: 0.87013392 . Updated MSE value: 1.63466724
# Updated b0 value: 2.78829139 . Updated b1 value: 0.76677122 . Updated MSE value: 1.65052169
# Updated b0 value: 2.85428313 . Updated b1 value: 0.82881089 . Updated MSE value: 1.58454691
# Updated b0 value: 2.73234743 . Updated b1 value: 0.75600307 . Updated MSE value: 1.71275203
# Updated b0 value: 2.46770932 . Updated b1 value: 0.57261758 . Updated MSE value: 2.22696386
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({
# /tmp/ipykernel_5040/304263236.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame({

# %%
prediction = pd.DataFrame({
    'x': sample_data.x
})
prediction["start"] = [beta00[0] + beta00[1]*x for x in prediction.x]
prediction["end"] = [task3.b0.iloc[-1] + task3.b1.iloc[-1]*x for x in prediction.x]
ax = sample_data.plot(x = 'x', y = 'y', kind = 'scatter')
prediction.plot(ax = ax, x = 'x')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
task3.plot(x = 'epoch', y = 'mse')
# Out:
# <AxesSubplot:xlabel='epoch'>

# %%
task3.plot(x = 'b1', y = 'b0', marker = ">")
# Out:
# <AxesSubplot:xlabel='b1'>

# %% [markdown]
# W przypadku SGD obliczenia potrzebne do aktualizacji parametrów są szybsze niż w GD, ale SGD może potrzebować więcej kroków niż GD, aby zminimalizować funkcję. Jest jeszcze jedna ważna przewaga SGD nad GD - SGD może „wydostać się” z lokalnego minimum.

# %% [markdown]
# Kolejnym krokiem w zrozumieniu procesu optymalizacji będzie implementacja SGD dla regresji logistycznej. W przypadku regresji logistycznej nie ma rozwiązania nuerycznego, więc musimy użyć jakiegoś algorytmu

# %%
spirals = pd.read_csv("data/spirals.csv")
spirals["intercept"] = 1
fig, ax = plt.subplots()

colors = {0:'red', 1:'blue'}

grouped = spirals.groupby('class')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])

plt.show()

# %% [markdown]
# Jak zawsze możemy sprawdzić rozwiązanie w Python. Python używa algorytmu scoringu Fishera lub algorytmu scoringu Newtona - algorytmy te wykorzystują nie tylko pierwszą, ale także drugą pochodną do aktualizacji parametrów. Korzystanie z drugiej pochodnej ma zalety, ale obliczenia są naprawdę czasochłonne i pochłaniają pamięć.

# %%
from sklearn.linear_model import LogisticRegression

X = np.array(spirals[["x", "y"]]).reshape(-1, 2)
y = np.array(spirals["class"]).reshape(-1, 1)

reg = LogisticRegression().fit(X, y)
print("b0", reg.intercept_)
print("b1 b2", reg.coef_)

# %%
X = np.concatenate((np.array(spirals["intercept"]).reshape(-1, 1), X), axis=1)

# %% [markdown]
# Następnym krokiem jest zaimplementowanie funkcji **sigmoid** używanej w regresji logistycznej:

# %%
sigmoid = lambda x: 1 / (1 + np.exp(-x))

# %% [markdown]
# i jej pochodnej:

# %%
sigmoid_grad = lambda x: sigmoid(x) * (1 - sigmoid(x))

# %% [markdown]
# W przypadku klasyfikacji binarnej naszą funkcją straty będzie **binary crossentropy**:

# %%
def binary_crossentropy(beta, X, y):
    z = sigmoid(np.matmul(beta, X.transpose()))
    return -np.mean(y * np.log(z) + (1 - y) * np.log(1 - z))

# %% [markdown]
# Potrzebujemy również gradientu. Tutaj zastosujemy tak zwaną **regułę łańcuchową** dla pochodnych:

# %%
def binary_crossentropy_grad(beta, X, y):
    z = sigmoid(np.matmul(beta, X.transpose()))
    dL = (-y[:,0] / z - (1 - y[:,0]) / (z - 1)) / y.shape[0]
    dV = sigmoid_grad(np.matmul(beta, X.transpose()))
    dx = X
    return np.matmul((dL * dV), dx)

# %% [markdown]
# Teraz mamy wszystko do zaimplementowania SGD do regresji logistycznej:

# %%
beta00 = np.array([0.3, 1, -0.2])
lr = 0.1
epochs = 50 # Liczba epok, czyli liczba aktualizacji wag (po całym datasecie)
batch_size = 20 # Liczba podzbiorów w datasecie

def SGD_logistic_regression(beta00, X, y, lr, epochs, batch_size):
    beta = beta00
    results = pd.DataFrame({
        'b0': [beta00[0]],
        'b1': [beta00[1]],
        'b2': [beta00[2]],
        'logloss': [binary_crossentropy(beta00, X, y)],
        'epoch': [0]
    })
    batches_per_epoch = int(np.ceil(y.shape[0] / batch_size))
    for i in range(1, epochs + 1):
        for b in range(1, batches_per_epoch + 1):
            X_b = X[((b - 1) * batch_size ):min((b * batch_size + 1), y.shape[0]), :]
            y_b = y[((b - 1) * batch_size ):min((b * batch_size + 1), y.shape[0]), :]
            beta = beta - lr * binary_crossentropy_grad(beta, X_b, y_b) # Stochastic Gradient Descent
            print("Updated b0 value:", round(beta[0], 8), ". Updated b1 value:", round(beta[1], 8), ". Updated b2 value:", round(beta[2], 8), ". Updated Logloss value:", round(binary_crossentropy(beta, X, y), 8))
            results = results.append(pd.DataFrame({
                'b0': [beta[0]],
                'b1': [beta[1]],
                'b2': [beta[2]],
                'logloss': [binary_crossentropy(beta, X, y)],
                'epoch': [i + b / batches_per_epoch]
    }))
    return results

task4 = SGD_logistic_regression(beta00, X, y, lr, epochs, batch_size)

# %%
task4.plot(x = 'epoch', y = 'logloss')

# %%
xy_grid = list(itertools.product(np.arange(spirals.x.min(), spirals.x.max(), 0.1),
           np.arange(spirals.y.min(), spirals.y.max(), 0.1)))
xy_grid = pd.DataFrame({
    'x': [z[0] for z in xy_grid],
    'y': [z[1] for z in xy_grid]
})
xy_grid["class"] = [task4.b0.iloc[-1] + task4.b1.iloc[-1]*x + task4.b2.iloc[-1]*y for x, y in zip(xy_grid.x, xy_grid.y)]
xy_grid["class"] = sigmoid(xy_grid["class"]) > 0.5
xy_grid["class"] = xy_grid["class"].astype(int)

# %%
fig, ax = plt.subplots()

colors = {0:'red', 1:'blue'}

grouped = xy_grid.groupby('class')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])

plt.show()
