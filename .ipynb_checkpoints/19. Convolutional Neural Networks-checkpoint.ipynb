# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import random
import os
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

tf.__version__
# Out:
# 2023-05-04 16:28:42.730479: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 16:28:45.245671: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.2/lib64:/usr/local/cuda-11.2/extras/CUPTI/lib64
# 2023-05-04 16:28:45.245867: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.2/lib64:/usr/local/cuda-11.2/extras/CUPTI/lib64
# 2023-05-04 16:28:45.245880: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# '2.11.0'

# %% [markdown]
# Zanim zbudujemy CNN w Keras, musimy zrozumieć konwolucję i pooling. Załaduj obraz „data/zebra.jpg”

# %%
zebra = tf.keras.preprocessing.image.load_img("data/zebra.jpg", color_mode = "grayscale", target_size = (200, 300))
zebra
# Out:
# <PIL.Image.Image image mode=L size=300x200 at 0x7F6799998BE0>

# %%
zebra_array = tf.keras.preprocessing.image.img_to_array(zebra) / 255
print(zebra_array.shape)
# Out:
# (200, 300, 1)

# %% [markdown]
# Teraz możemy zaimplementować prostą konwolucję:

# %%
sobel_filter_x = np.transpose(np.array([1, 2, 1, 0, 0, 0, -1, -2, -1]).reshape((3, 3)))
sobel_filter_x
# Out:
# array([[ 1,  0, -1],
#        [ 2,  0, -2],
#        [ 1,  0, -1]])

# %%
kernel_shape = 3
padding = 0
stride = 1
input_height = zebra_array.shape[0]
input_width = zebra_array.shape[1]
activation_map_height = int((input_height + 2 * padding - kernel_shape) / stride + 1)
activation_map_width = int((input_width + 2 * padding - kernel_shape) / stride + 1)
activation_map = np.zeros((activation_map_height, activation_map_width))

# %%
for w in range(0, activation_map_width):
    for h in range(0, activation_map_height):
        activation_map[h, w] = np.sum(sobel_filter_x * zebra_array[h:(h + kernel_shape), w:(w + kernel_shape), 0])

# %%
plt.matshow(activation_map)

# %% [markdown]
# oraz pooling:

# %%
pool_shape = 2
pool_stride = 2
activation_map2_height = int(activation_map_height / pool_shape)
activation_map2_width = int(activation_map_width / pool_shape)
activation_map2 = np.zeros((activation_map2_height, activation_map2_width))

# %%
for w in range(0, activation_map2_width):
    for h in range(0, activation_map2_height):
        activation_map2[h, w] = np.max(activation_map[(2 * h):((2 * h) + pool_shape), (2 * w):((2 * w) + pool_shape)])

# %%
plt.matshow(activation_map2)

# %% [markdown]
# Zaczniemy od zbudowania prostego CNN dla zbioru danych dotyczących mody. Na pierwszym spotkaniu stworzyliśmy MLP do tego zadania. Załadujmy zbiór danych:

# %%
fashion_mnist_train_X = pd.read_csv("data/fashion_mnist_train_X", sep=" ").to_numpy()
fashion_mnist_test_X = pd.read_csv("data/fashion_mnist_test_X", sep=" ").to_numpy()
fashion_mnist_train_Y = pd.read_csv("data/fashion_mnist_train_Y", sep=" ").to_numpy()
fashion_mnist_test_Y = pd.read_csv("data/fashion_mnist_test_Y", sep=" ").to_numpy()

fashion_mnist_train_X = fashion_mnist_train_X / 255
fashion_mnist_test_X = fashion_mnist_test_X / 255

print(fashion_mnist_train_X.shape)
print(fashion_mnist_train_Y.shape)
# Out:
# (60000, 784)
# (60000, 1)

# %%
plt.matshow(fashion_mnist_train_X[0,:].reshape((28,28)))

# %% [markdown]
# Aby przesłać dane do modelu CNN w keras, musimy przekształcić je w odpowiednie tensory. Podobnie jak w przypadku MLP musimy przekształcić wektor etykiet do macierzy z kodowaniem one-hot-encoding. W przypadku naszych obrazów musimy przedstawić je jako tensor 4-wymiarowy (próbki, wysokość, szerokość, kanały). Musimy również pamiętać o znormalizowaniu wartości pikseli:

# %%
fashion_mnist_train_Y = tf.keras.utils.to_categorical(fashion_mnist_train_Y, 10)
fashion_mnist_test_Y = tf.keras.utils.to_categorical(fashion_mnist_test_Y, 10)

fashion_mnist_train_X = fashion_mnist_train_X.reshape(-1, 28, 28, 1)
fashion_mnist_test_X = fashion_mnist_test_X.reshape(-1, 28, 28, 1)
print(fashion_mnist_train_X.shape)
print(fashion_mnist_train_Y.shape)
# Out:
# (60000, 28, 28, 1)
# (60000, 10)

# %% [markdown]
# Dane są w poprawnej formie tensorowej, możemy przystąpić do budowy modelu. Jak zawsze będzie to model sekwencyjny. Jako pierwszą warstwę użyjemy warstwy konwolucyjnej:

# %%
fmnist_model1 = tf.keras.Sequential()

fmnist_model1.add(
    tf.keras.layers.Conv2D(filters = 32, # Liczba filtrów
                           kernel_size = (3, 3), # Wielkość filtrów
                           activation = 'relu',
                            input_shape = (28, 28, 1))
)
fmnist_model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        320
#
# =================================================================
# Total params: 320
# Trainable params: 320
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Dlaczego mamy do wytrenowania 320 parametrów?

# %%
32 * (3 * 3 * 1 + 1) # 32 filters of size 3x3(x1) + bias for each of them
# Out:
# 320

# %% [markdown]
# Dlaczego output ma kształt (None, 26, 26, 32) ?

# %%
((28 - 3 + 2 * 0) / 1) + 1 # 28 - input image size, 3 - kernsl size, 0 - padding, 1 - stride
# Out:
# 26.0

# %% [markdown]
# Po warstwie konwolucyjnej możemy dodać kolejną. Użyjmy warstwy max pooling:

# %%
fmnist_model1.add(
    tf.keras.layers.MaxPool2D(pool_size = (2, 2))
)
fmnist_model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
# =================================================================
# Total params: 320
# Trainable params: 320
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Dlaczego output ma kształt (None, 13, 13, 32) ?

# %%
26 / 2 # 26 - input of the activation map shape, 2 - pool size
# Out:
# 13.0

# %% [markdown]
# Powiedzmy, że chcemy dokończyć naszą architekturę i dodać warstwę wyjściową. zrobimy to w taki sam sposób jak w MLP, ale zanim to zrobimy, musimy spłaszczyć naszą ostatnią mapę aktywacji do wektora:

# %%
fmnist_model1.add(
    tf.keras.layers.Flatten()
)

fmnist_model1.add(
    tf.keras.layers.Dense(units = 10, activation = "softmax")
)
fmnist_model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  flatten (Flatten)           (None, 5408)              0
#
#  dense (Dense)               (None, 10)                54090
#
# =================================================================
# Total params: 54,410
# Trainable params: 54,410
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Dlaczego output ma kształt (None, 5408) ?

# %%
13 * 13 * 32 # Check dimmentions of previous layer
# Out:
# 5408

# %% [markdown]
# Dlaczego mamy 54090 parametrów do trenowania w warstwie wyjściowej?

# %%
5408 * 10 + 10 # 5408 - from layer_flatten * 10 neurons + biases
# Out:
# 54090

# %% [markdown]
# Architertura CNN jest ukończona, możemy teraz skompilować model:

# %%
fmnist_model1.compile(
    optimizer = "sgd",
    loss = "categorical_crossentropy",
    metrics = ("accuracy"))

# %% [markdown]
# i go wytrenować:

# %%
history = fmnist_model1.fit(
    x = fashion_mnist_train_X,
    y = fashion_mnist_train_Y,
    validation_split = 0.2, # 20% zbioru uczącego przeznaczonego na walidację
    epochs = 30, # Liczba "pętli/przejść" bo całym zbiorze treningowym
    batch_size = 128, # Wielkość próbki (batcha) dla jednej iteracji algorytmu SGD
    verbose = 1,
    callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath = "models/fmnist_model1_best.hdf5",
                                                  monitor = "val_loss", save_best_only = True)])
# Out:
# Epoch 1/30
# 2023-05-04 16:42:08.226800: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8101
# 2023-05-04 16:42:11.034178: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f63aca033a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-04 16:42:11.034258: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1070, Compute Capability 6.1
# 2023-05-04 16:42:11.397757: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 375/375 [==============================] - 7s 5ms/step - loss: 1.0989 - accuracy: 0.6590 - val_loss: 0.7196 - val_accuracy: 0.7535
# Epoch 2/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6527 - accuracy: 0.7742 - val_loss: 0.6327 - val_accuracy: 0.7793
# Epoch 3/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5826 - accuracy: 0.7936 - val_loss: 0.5853 - val_accuracy: 0.7854
# Epoch 4/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5473 - accuracy: 0.8054 - val_loss: 0.5666 - val_accuracy: 0.7987
# Epoch 5/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5282 - accuracy: 0.8117 - val_loss: 0.5224 - val_accuracy: 0.8161
# Epoch 6/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5119 - accuracy: 0.8166 - val_loss: 0.5068 - val_accuracy: 0.8245
# Epoch 7/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4979 - accuracy: 0.8235 - val_loss: 0.5366 - val_accuracy: 0.8120
# Epoch 8/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4889 - accuracy: 0.8248 - val_loss: 0.5026 - val_accuracy: 0.8217
# Epoch 9/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4841 - accuracy: 0.8283 - val_loss: 0.4884 - val_accuracy: 0.8265
# Epoch 10/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4728 - accuracy: 0.8332 - val_loss: 0.4765 - val_accuracy: 0.8330
# Epoch 11/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4685 - accuracy: 0.8334 - val_loss: 0.4859 - val_accuracy: 0.8313
# Epoch 12/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4598 - accuracy: 0.8374 - val_loss: 0.5022 - val_accuracy: 0.8237
# Epoch 13/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4542 - accuracy: 0.8400 - val_loss: 0.4575 - val_accuracy: 0.8446
# Epoch 14/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4475 - accuracy: 0.8422 - val_loss: 0.4939 - val_accuracy: 0.8261
# Epoch 15/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4398 - accuracy: 0.8460 - val_loss: 0.4477 - val_accuracy: 0.8464
# Epoch 16/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4378 - accuracy: 0.8472 - val_loss: 0.4540 - val_accuracy: 0.8396
# Epoch 17/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4290 - accuracy: 0.8494 - val_loss: 0.4346 - val_accuracy: 0.8524
# Epoch 18/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4236 - accuracy: 0.8521 - val_loss: 0.4444 - val_accuracy: 0.8471
# Epoch 19/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4199 - accuracy: 0.8526 - val_loss: 0.4284 - val_accuracy: 0.8548
# Epoch 20/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4170 - accuracy: 0.8526 - val_loss: 0.4377 - val_accuracy: 0.8443
# Epoch 21/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4097 - accuracy: 0.8562 - val_loss: 0.4231 - val_accuracy: 0.8546
# Epoch 22/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4062 - accuracy: 0.8584 - val_loss: 0.4144 - val_accuracy: 0.8593
# Epoch 23/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4020 - accuracy: 0.8603 - val_loss: 0.4207 - val_accuracy: 0.8537
# Epoch 24/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3979 - accuracy: 0.8611 - val_loss: 0.4337 - val_accuracy: 0.8472
# Epoch 25/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3930 - accuracy: 0.8630 - val_loss: 0.4135 - val_accuracy: 0.8569
# Epoch 26/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3904 - accuracy: 0.8642 - val_loss: 0.3988 - val_accuracy: 0.8638
# Epoch 27/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3888 - accuracy: 0.8658 - val_loss: 0.4073 - val_accuracy: 0.8589
# Epoch 28/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3844 - accuracy: 0.8661 - val_loss: 0.4053 - val_accuracy: 0.8609
# Epoch 29/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3802 - accuracy: 0.8683 - val_loss: 0.4132 - val_accuracy: 0.8543
# Epoch 30/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3776 - accuracy: 0.8690 - val_loss: 0.3995 - val_accuracy: 0.8608

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# oraz zewaluować na zbiorze testowym:

# %%
fmnist_model1.evaluate(fashion_mnist_test_X, fashion_mnist_test_Y)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3897 - accuracy: 0.8703
# [0.389699250459671, 0.8702999949455261]

# %% [markdown]
# Czas na stworzenie bardziej zaawansowanej wersji tego modelu:

# %%
# Zainicjalizuj model sekwencyjny
fmnist_model2 = tf.keras.Sequential()

# Dodaj warstwę konwolucji 2D z 128 filtrami, wielkością kernela 3x3,
# liniową funkcją aktywacji, padding "same", i odpowiednim inputem
fmnist_model2.add(
    tf.keras.layers.Conv2D(filters=128, kernel_size=3, strides=1,
                          activation='linear', padding='same',
                          input_shape=(28,28,1))
)

# Dodaj warstwę BatchNormalization
fmnist_model2.add(
    tf.keras.layers.BatchNormalization()
)

# Dodaj warstwę ReLU
fmnist_model2.add(
    tf.keras.layers.ReLU()
)

# Dodaj warstwę poolingu 2D z pool_size z wiekością 2x2 i stride 2x2
fmnist_model2.add(
    tf.keras.layers.MaxPool2D(pool_size=(2,2))
)

# Dodaj dropout 25%
fmnist_model2.add(
    tf.keras.layers.Dropout(0.25)
)

# Dodaj warstwę spłaszczającą
fmnist_model2.add(
    tf.keras.layers.Flatten()
)

# dodaj warstwę wyjścia
fmnist_model2.add(
    tf.keras.layers.Dense(units = 10, activation = "softmax")
)

fmnist_model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       1280
#
#  batch_normalization (BatchN  (None, 28, 28, 128)      512
#  ormalization)
#
#  re_lu (ReLU)                (None, 28, 28, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 14, 14, 128)       0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_1 (Dense)             (None, 10)                250890
#
# =================================================================
# Total params: 252,682
# Trainable params: 252,426
# Non-trainable params: 256
# _________________________________________________________________

# %%
fmnist_model2.compile(
    optimizer = tf.keras.optimizers.Adadelta(learning_rate = 0.01),
    loss = "categorical_crossentropy",
    metrics = ("accuracy"))

# %%
if not os.path.exists("tensorboard"):
    os.mkdir("tensorboard")

history = fmnist_model1.fit(
    x = fashion_mnist_train_X,
    y = fashion_mnist_train_Y,
    validation_split = 0.2, # 20% zbioru uczącego przeznaczonego na walidację
    epochs = 30, # Liczba "pętli/przejść" bo całym zbiorze treningowym
    batch_size = 128, # Wielkość próbki (batcha) dla jednej iteracji algorytmu SGD
    verbose = 1,
    callbacks = [tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 5),
                 tf.keras.callbacks.ModelCheckpoint(filepath = "models/fmnist_model2_best.hdf5",
                                                  monitor = "val_accuracy", save_best_only = True),
                tf.keras.callbacks.TensorBoard(log_dir = "tensorboard")])
# Out:
# Epoch 1/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3756 - accuracy: 0.8695 - val_loss: 0.3868 - val_accuracy: 0.8702
# Epoch 2/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3702 - accuracy: 0.8723 - val_loss: 0.3853 - val_accuracy: 0.8708
# Epoch 3/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3689 - accuracy: 0.8723 - val_loss: 0.3830 - val_accuracy: 0.8695
# Epoch 4/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3658 - accuracy: 0.8748 - val_loss: 0.3813 - val_accuracy: 0.8692
# Epoch 5/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3634 - accuracy: 0.8747 - val_loss: 0.3768 - val_accuracy: 0.8733
# Epoch 6/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3616 - accuracy: 0.8755 - val_loss: 0.3767 - val_accuracy: 0.8734
# Epoch 7/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3570 - accuracy: 0.8769 - val_loss: 0.3992 - val_accuracy: 0.8588
# Epoch 8/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3558 - accuracy: 0.8779 - val_loss: 0.3698 - val_accuracy: 0.8726
# Epoch 9/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3535 - accuracy: 0.8775 - val_loss: 0.3709 - val_accuracy: 0.8758
# Epoch 10/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3505 - accuracy: 0.8784 - val_loss: 0.3911 - val_accuracy: 0.8640
# Epoch 11/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3484 - accuracy: 0.8797 - val_loss: 0.3686 - val_accuracy: 0.8748
# Epoch 12/30
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3470 - accuracy: 0.8810 - val_loss: 0.3705 - val_accuracy: 0.8733
# Epoch 13/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3455 - accuracy: 0.8798 - val_loss: 0.3622 - val_accuracy: 0.8763
# Epoch 14/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3425 - accuracy: 0.8822 - val_loss: 0.3649 - val_accuracy: 0.8765
# Epoch 15/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3410 - accuracy: 0.8824 - val_loss: 0.3653 - val_accuracy: 0.8769
# Epoch 16/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3386 - accuracy: 0.8840 - val_loss: 0.3716 - val_accuracy: 0.8711
# Epoch 17/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3382 - accuracy: 0.8826 - val_loss: 0.3837 - val_accuracy: 0.8649
# Epoch 18/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3351 - accuracy: 0.8844 - val_loss: 0.3568 - val_accuracy: 0.8761
# Epoch 19/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3341 - accuracy: 0.8856 - val_loss: 0.3536 - val_accuracy: 0.8803
# Epoch 20/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3317 - accuracy: 0.8867 - val_loss: 0.3545 - val_accuracy: 0.8768
# Epoch 21/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3319 - accuracy: 0.8853 - val_loss: 0.3505 - val_accuracy: 0.8791
# Epoch 22/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3290 - accuracy: 0.8861 - val_loss: 0.3543 - val_accuracy: 0.8783
# Epoch 23/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3268 - accuracy: 0.8888 - val_loss: 0.3495 - val_accuracy: 0.8798
# Epoch 24/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3260 - accuracy: 0.8882 - val_loss: 0.3495 - val_accuracy: 0.8788

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# %load_ext tensorboard
# %tensorboard --logdir tensorboard
# Out:
#       <iframe id="tensorboard-frame-947fb3415183e39f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-947fb3415183e39f");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
